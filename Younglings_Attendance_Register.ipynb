# %%
#import pandas in Jupyter Notebook  environment:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading from a file
myFile =pd.read_csv("MonthlyAttendance.csv")

# %%
myFile.head() #showing the first 5 rows of a data frame or series
# Out:
#   Employee Name   Surname 4/5/2021 4/6/2021   4/7/2021  4/8/2021 4/9/2021  \
# 0           NaN       NaN   Monday  Tuesday  Wednesday  Thursday   Friday
# 1        Amanda       Mxi      NaN        P          P         P        P
# 2        Anathi     Dwala      NaN        P          P         P        P
# 3      Aphelele     Xwayi      NaN        P          P         P        P
# 4        Aphiwe  Nxolongo      NaN        P          P         P        P
#
#   4/13/2021  4/14/2021 4/15/2021  ...  4/21/2021 4/22/2021 4/23/2021  \
# 0   Tuesday  Wednesday  Thursday  ...  Wednesday  Thursday    Friday
# 1         P          P         P  ...          P         P         P
# 2         P          P         P  ...          P         P         P
# 3         P          P         A  ...          P         P         P
# 4         P          P         P  ...          P         P         P
#
#   4/26/2021 4/27/2021  4/28/2021 4/29/2021 4/30/2021 Total days Present  \
# ...

# %%
myFile.tail() #showing the last 8 rows of a dataframe or series
# Out:
#          Employee Name    Surname 4/5/2021 4/6/2021 4/7/2021 4/8/2021  \
# 47              Zaynab    Hartley      NaN        P        P        P
# 48             Zingisa     Mbanga      NaN        P        P        P
# 49  Zizipho Christabel       Kuza      NaN        A        A        A
# 50                Zizo     Sogoni      NaN        P        P        P
# 51                Yves  Cyubahiro      NaN        P        P        P
#
#    4/9/2021 4/13/2021 4/14/2021 4/15/2021  ... 4/21/2021 4/22/2021 4/23/2021  \
# 47        P         P         P         P  ...         P         P         P
# 48        P         P         P         P  ...         P         P         P
# 49        A         A         P         P  ...         A         A         A
# 50        P         P         P         P  ...         P         P         P
# 51        P         P         P         P  ...         P         P         P
#
#    4/26/2021 4/27/2021 4/28/2021 4/29/2021 4/30/2021 Total days Present  \
# ...

# %%
myFile.isna().sum()
# Out:
# Employee Name          1
#   Surname              1
# 4/5/2021              51
# 4/6/2021               0
# 4/7/2021               0
# 4/8/2021               0
# 4/9/2021               0
# 4/13/2021              0
# 4/14/2021              0
# 4/15/2021              0
# 4/16/2021              0
# 4/19/2021              0
# 4/20/2021              0
# 4/21/2021              0
# 4/22/2021              0
# 4/23/2021              0
# 4/26/2021              0
# 4/27/2021             51
# 4/28/2021              0
# 4/29/2021              0
# 4/30/2021              0
# Total days Present     1
# Total days Absent      1
# dtype: int64

# %%
myFile.drop_duplicates()
# Out:
#          Employee Name     Surname 4/5/2021 4/6/2021   4/7/2021  4/8/2021  \
# 0                  NaN         NaN   Monday  Tuesday  Wednesday  Thursday
# 1               Amanda         Mxi      NaN        P          P         P
# 2               Anathi       Dwala      NaN        P          P         P
# 3             Aphelele       Xwayi      NaN        P          P         P
# 4               Aphiwe    Nxolongo      NaN        P          P         P
# 5              Artrhur      Butler      NaN        P          P         P
# 6             Asemahle       Skoti      NaN        A          A         A
# 7                Azile      Magaba      NaN        P          P         P
# 8                Azola    Mafilika      NaN        P          P         P
# 9              Babalwa      Magada      NaN        P          A         P
# 10             Bangile    Mahlamvu      NaN        P          P         P
# 11               Chuma    Tsheyini      NaN        P          A         P
# ...

# %%
myFile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee Name       51 non-null     object
#  1     Surname           51 non-null     object
#  2   4/5/2021            1 non-null      object
#  3   4/6/2021            52 non-null     object
#  4   4/7/2021            52 non-null     object
#  5   4/8/2021            52 non-null     object
#  6   4/9/2021            52 non-null     object
#  7   4/13/2021           52 non-null     object
#  8   4/14/2021           52 non-null     object
#  9   4/15/2021           52 non-null     object
#  10  4/16/2021           52 non-null     object
#  11  4/19/2021           52 non-null     object
#  12  4/20/2021           52 non-null     object
#  13  4/21/2021           52 non-null     object
#  14  4/22/2021           52 non-null     object
# ...

# %%
myFile.columns
# Out:
# Index(['Employee Name', '  Surname', '4/5/2021', '4/6/2021', '4/7/2021',
#        '4/8/2021', '4/9/2021', '4/13/2021', '4/14/2021', '4/15/2021',
#        '4/16/2021', '4/19/2021', '4/20/2021', '4/21/2021', '4/22/2021',
#        '4/23/2021', '4/26/2021', '4/27/2021', '4/28/2021', '4/29/2021',
#        '4/30/2021', 'Total days Present', 'Total days Absent'],
#       dtype='object')

# %%
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Days absent": [0,0,1,0,0,17,0,0,3,1,2,0,0,0,17,7,2,2,0,3,0,1,0,0,16,0,10,2,4,5,1,2,1,0,0,0,1,0,3,15,1,0,0,0,0,0,2,14,0,4]}, 
    index=["Amanda","Anathi","Aphelele","Aphiwe","Arthur","Asemahle","Azile","Azola","Babalwa","Bangile","Chuma","Chwayita","Enrico","Esona D","Esona G", "Gobusamang","Lazola","Londoloza","Lulama","Luvo","Lwandile","Mogamat Naeem","Mothusi","Nicholas","Nobulali","Nosiphiwo","Ntokozo","Qhawe","Rayaan","Rudzani","Sakhe","Samantha","Scott","Shane","Sibonokuhle","Sikhosonke","Silungile","Sinethemba","Siyabonga","Thamsanqa","Vuyisa","Xolisa","Yamkela","Yonella","Zaakirah","Zaynab","Zingisa","Zizipho","Zizo","Yves"])
# Plot a bar chart
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Days present": [17,17,16,17,17,0,17,17,14,16,15,17,17,17,0,10,15,15,17,14,17,16,17,17,1,17,7,15,13,12,16,17,17,17,16,17,14,2,16,17,17,17,17,17,17,3,15,3,17,13]}, 
    index=["Amanda","Anathi","Aphelele","Aphiwe","Arthur","Asemahle","Azile","Azola","Babalwa","Bangile","Chuma","Chwayita","Enrico","Esona D","Esona G", "Gobusamang","Lazola","Londoloza","Lulama","Luvo","Lwandile","Mogamat Naeem","Mothusi","Nicholas","Nobulali","Nosiphiwo","Ntokozo","Qhawe","Rayaan","Rudzani","Sakhe","Samantha","Scott","Shane","Sibonokuhle","Sikhosonke","Silungile","Sinethemba","Siyabonga","Thamsanqa","Vuyisa","Xolisa","Yamkela","Yonella","Zaakirah","Zaynab","Zingisa","Zizipho","Zizo","Yves"])
# Plot a bar chart
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Days present": [17,17,16,17,17,0,17,17,14,16,15,17,17,17,0,10,15,15,17,14,17,16,17,17,1,17,7,15,13,12,16,17,17,17,16,17,14,2,16,17,17,17,17,17,17,3,15,3,17,13]}, 
    index=["Amanda","Anathi","Aphelele","Aphiwe","Arthur","Asemahle","Azile","Azola","Babalwa","Bangile","Chuma","Chwayita","Enrico","Esona D","Esona G", "Gobusamang","Lazola","Londoloza","Lulama","Luvo","Lwandile","Mogamat Naeem","Mothusi","Nicholas","Nobulali","Nosiphiwo","Ntokozo","Qhawe","Rayaan","Rudzani","Sakhe","Samantha","Scott","Shane","Sibonokuhle","Sikhosonke","Silungile","Sinethemba","Siyabonga","Thamsanqa","Vuyisa","Xolisa","Yamkela","Yonella","Zaakirah","Zaynab","Zingisa","Zizipho","Zizo","Yves"])
# Plot a bar chart
plotdata.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Days absent": [0,0,1,0,0,17,0,0,3,1,2,0,0,0,17,7,2,2,0,3,0,1,0,0,16,0,10,2,4,5,1,2,1,0,0,0,1,0,3,15,1,0,0,0,0,0,2,14,0,4]}, 
    index=["Amanda","Anathi","Aphelele","Aphiwe","Arthur","Asemahle","Azile","Azola","Babalwa","Bangile","Chuma","Chwayita","Enrico","Esona D","Esona G", "Gobusamang","Lazola","Londoloza","Lulama","Luvo","Lwandile","Mogamat Naeem","Mothusi","Nicholas","Nobulali","Nosiphiwo","Ntokozo","Qhawe","Rayaan","Rudzani","Sakhe","Samantha","Scott","Shane","Sibonokuhle","Sikhosonke","Silungile","Sinethemba","Siyabonga","Thamsanqa","Vuyisa","Xolisa","Yamkela","Yonella","Zaakirah","Zaynab","Zingisa","Zizipho","Zizo","Yves"])
# Plot a bar chart
plotdata.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Days absent": [0,0,1,0,0,17,0,0,3,1,2,0,0,0,17,7,2,2,0,3,0,1,0,0,16,0,10,2,4,5,1,2,1,0,0,0,1,0,3,15,1,0,0,0,0,0,2,14,0,4]}, 
    index=["Amanda","Anathi","Aphelele","Aphiwe","Arthur","Asemahle","Azile","Azola","Babalwa","Bangile","Chuma","Chwayita","Enrico","Esona D","Esona G", "Gobusamang","Lazola","Londoloza","Lulama","Luvo","Lwandile","Mogamat Naeem","Mothusi","Nicholas","Nobulali","Nosiphiwo","Ntokozo","Qhawe","Rayaan","Rudzani","Sakhe","Samantha","Scott","Shane","Sibonokuhle","Sikhosonke","Silungile","Sinethemba","Siyabonga","Thamsanqa","Vuyisa","Xolisa","Yamkela","Yonella","Zaakirah","Zaynab","Zingisa","Zizipho","Zizo","Yves"])
# Plot a bar chart
plotdata.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Days present": [17,17,16,17,17,0,17,17,14,16,15,17,17,17,0,10,15,15,17,14,17,16,17,17,1,17,7,15,13,12,16,17,17,17,16,17,14,2,16,17,17,17,17,17,17,3,15,3,17,13]}, 
    index=["Amanda","Anathi","Aphelele","Aphiwe","Arthur","Asemahle","Azile","Azola","Babalwa","Bangile","Chuma","Chwayita","Enrico","Esona D","Esona G", "Gobusamang","Lazola","Londoloza","Lulama","Luvo","Lwandile","Mogamat Naeem","Mothusi","Nicholas","Nobulali","Nosiphiwo","Ntokozo","Qhawe","Rayaan","Rudzani","Sakhe","Samantha","Scott","Shane","Sibonokuhle","Sikhosonke","Silungile","Sinethemba","Siyabonga","Thamsanqa","Vuyisa","Xolisa","Yamkela","Yonella","Zaakirah","Zaynab","Zingisa","Zizipho","Zizo","Yves"])
# Plot a bar chart
plotdata.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
